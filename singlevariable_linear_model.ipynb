# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import pandas as pd

df=pd.read_csv('canada_per_capita_income.csv')
plt.xlabel('year')
plt.ylabel('per capita')
plt.scatter(df['year'], df['per capita income'], marker='+', color='red')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income'])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
